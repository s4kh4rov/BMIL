# %% [markdown]
# <a href="https://colab.research.google.com/github/s4kh4rov/BMIL/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! apt install tesseract-ocr
! apt install libtesseract-dev
# !pip install pytesseract==5.0.0
# !pip install Pillow==9.1.0
# !pip install PIL
from PIL import Image
import cv2 
import pytesseract
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libtesseract-dev is already the newest version (4.00~git2288-10f4998a-2).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# ...

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

# %%
# !pip install imutils
import imutils
img = cv2.imread('/content/drive/MyDrive/t/1.jpg')
cv2_imshow(img)
# img=cv2.resize(img,None,fx=0.5,fy=0.5)
# gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# theshold = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,85,11)
# cv2_imshow(theshold)
# config = r'--oem 3 --psm 6'
# print(pytesseract.image_to_string(img, config=config))
# text=pytesseract.image_to_string(theshold)
# print('----',text)


# img2 = imutils.resize(img, width=1280)
# cv2_imshow(img2)


# text=pytesseract.image_to_string(img)
# print("--------")
# print(text)
# print("--------")

img1 = get_grayscale(img)
img1 = cv2.medianBlur(img1, 3)
(thresh, img1) = cv2.threshold(img1, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
img1 = cv2.bitwise_not(img1)
cv2_imshow(img1)
text=pytesseract.image_to_string(img1)
print("--------")
print(text)
print("--------")
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")
 
# to search
query = text
 
for j in search(query, tld="co.in", num=3, stop=3, pause=2):
    print(j)
# Out:
# <PIL.Image.Image image mode=RGB size=958x238>
# <PIL.Image.Image image mode=L size=479x119>
# ~ Domino's ™
#
# ----

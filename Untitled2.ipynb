# %% [markdown]
# <a href="https://colab.research.google.com/github/s4kh4rov/BMIL/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! apt install tesseract-ocr
#! apt install libtesseract-dev
#!pip install pytesseract
#!pip install Pillow==9.1.0
#!pip install PIL
from PIL import Image
import cv2 
import pytesseract
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
# <PIL.Image.Image image mode=RGB size=498x228>
# --------
#
#
# --------
# <PIL.Image.Image image mode=L size=498x228>
# --------
#
# --------

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

# %%
img = cv2.imread('/content/sample_data/ozon.jpg')
cv2_imshow(img)
text=pytesseract.image_to_string(img)
print("--------")
print(text)
print("--------")

img1 = get_grayscale(img)
(thresh, img1) = cv2.threshold(img1, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2_imshow(img1)
text=pytesseract.image_to_string(img1)
print("--------")
print(text)
print("--------")
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")
 
# to search
query = text
 
for j in search(query, tld="co.in", num=3, stop=3, pause=2):
    print(j)
# Out:
# <PIL.Image.Image image mode=RGB size=606x156>
# --------
#
#
# --------
# <PIL.Image.Image image mode=L size=606x156>
# --------
# OZON
#
# --------
# https://www.ozon.ru/
# https://business.ozon.ru/
# https://www.ozon.ru/my/main/
